# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mp

# %% [markdown]
# # Ligand 9

# %% [markdown]
# ## Ligand

# %%
# times, ligand_water_distances, histidine_water_distances1, histidine_water_distances2, arginine_water_distances1, arginine_water_distances2
raw_data = np.load("../outputs/water_hb_ligand_9_his_arg.npy", allow_pickle=True)
data = np.array([raw_data[0], raw_data[1]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "ligand"])

avg = np.mean(dataframe["ligand"])
print(avg)
med = np.median(dataframe["ligand"])
print(med)
std = np.std(dataframe["ligand"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="ligand", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["ligand"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["ligand"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()
plt.savefig("../../plots/water_mediated_hydrogen_bonds/ligand_9.pdf")
# Out:
# 3.5139299854777124
# 3.3584631323198675
# 0.7278970257114827

# %% [markdown]
# ## Histidine 1

# %%
data = np.array([raw_data[0], raw_data[2]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "his1"])
avg = np.mean(dataframe["his1"])
print(avg)
med = np.median(dataframe["his1"])
print(med)
std = np.std(dataframe["his1"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="his1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["his1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["his1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")
plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/lig9_his1.pdf")
# Out:
# 3.642786390034217
# 3.6580699122025613
# 0.6319089739909841

# %% [markdown]
# ## Histidine 2

# %%
data = np.array([raw_data[0], raw_data[3]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "his2"])
avg = np.mean(dataframe["his2"])
print(avg)
std = np.std(dataframe["his2"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="his2", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["his2"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["his2"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()
plt.savefig("../../plots/water_mediated_hydrogen_bonds/lig9_his2.pdf")
# Out:
# 2.957957348655554
# 0.8300171332559915

# %% [markdown]
# ## Arginine 1

# %%
data = np.array([raw_data[0], raw_data[4]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "arg1"])
avg = np.mean(dataframe["arg1"])
print(avg)
med = np.median(dataframe["arg1"])
print(med)

plot = sns.jointplot(data=dataframe, x="time", y="arg1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["arg1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["arg1"], color="black", alpha=0.8)
plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
# Out:
# 3.0136466890204634
# 2.890734921123773

# %% [markdown]
# ## Arginine 2

# %%
data = np.array([raw_data[0], raw_data[4]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "arg2"])
avg = np.mean(dataframe["arg2"])
print(avg)
std = np.std(dataframe["arg2"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="arg2", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["arg2"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["arg2"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/lig9_arg2.pdf")
# Out:
# 3.0136466890204634
# 0.6363465011025399

# %% [markdown]
# # Ligand 15

# %% [markdown]
# ## Ligand

# %%
# times, ligand_water_distances, histidine_water_distances1, histidine_water_distances2, arginine_water_distances1, arginine_water_distances2
raw_data = np.load("../outputs/water_hb_ligand_15_his_arg.npy", allow_pickle=True)
data = np.array([raw_data[0], raw_data[1]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "ligand"])

avg = np.mean(dataframe["ligand"])
print(avg)
med = np.median(dataframe["ligand"])
print(med)
std = np.std(dataframe["ligand"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="ligand", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["ligand"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["ligand"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/ligand_15.pdf")
# Out:
# 6.883653114905717
# 6.909241431867557
# 1.4078424648094625

# %% [markdown]
# ## Histidine

# %%
data = np.array([raw_data[0], raw_data[2]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "his1"])
avg = np.mean(dataframe["his1"])
print(avg)
med = np.median(dataframe["his1"])
print(med)
std = np.std(dataframe["his1"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="his1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["his1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["his1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/lig15_his1.pdf")
# Out:
# 3.8280471528996163
# 3.759970768467599
# 0.7900826621560216

# %% [markdown]
# ## Arginine

# %%
data = np.array([raw_data[0], raw_data[4]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "arg1"])
avg = np.mean(dataframe["arg1"])
print(avg)
med = np.median(dataframe["arg1"])
print(med)
std = np.std(dataframe["arg1"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="arg1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["arg1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["arg1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/lig15_arg1.pdf")
# Out:
# 3.681547360059066
# 3.5286216070463725
# 0.759014008297248

# %% [markdown]
# # Ligand 16

# %% [markdown]
# ## Ligand

# %%
# times, ligand_water_distances, histidine_water_distances1, histidine_water_distances2, arginine_water_distances1, arginine_water_distances2
raw_data = np.load("../outputs/water_hb_ligand_16_his_arg.npy", allow_pickle=True)
data = np.array([raw_data[0], raw_data[1]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "ligand"])

avg = np.mean(dataframe["ligand"])
print(avg)
med = np.median(dataframe["ligand"])
print(med)
std = np.std(dataframe["ligand"])
print(std)
plot = sns.jointplot(data=dataframe, x="time", y="ligand", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["ligand"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["ligand"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/ligand_16.pdf")
# Out:
# 4.5455506966817785
# 4.153734533373125
# 1.4979705091670743

# %% [markdown]
# ## Histidine

# %%
data = np.array([raw_data[0], raw_data[2]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "his1"])
avg = np.mean(dataframe["his1"])
print(avg)
med = np.median(dataframe["his1"])
print(med)
std = np.std(dataframe["his1"])
print(std)
plot = sns.jointplot(data=dataframe, x="time", y="his1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["his1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["his1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
# Out:
# 4.269541758123315
# 4.006578468696393
# 1.109457984288148

# %%
data = np.array([raw_data[0], raw_data[3]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "his2"])
avg = np.mean(dataframe["his2"])
print(avg)
med = np.median(dataframe["his2"])
print(med)
std = np.std(dataframe["his2"])
print(std)

plot = sns.jointplot(data=dataframe, x="time", y="his2", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["his2"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["his2"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/lig16_his2.pdf")
# Out:
# 2.993426641249119
# 2.8424974864782833
# 0.8929073659783426

# %% [markdown]
# ## Arginine

# %%
data = np.array([raw_data[0], raw_data[4]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "arg1"])
avg = np.mean(dataframe["arg1"])
print(avg)
med = np.median(dataframe["arg1"])
print(med)
std = np.std(dataframe["arg1"])
print(std)
plot = sns.jointplot(data=dataframe, x="time", y="arg1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["arg1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["arg1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()

plt.savefig("../../plots/water_mediated_hydrogen_bonds/lig16_arg1.pdf")
# Out:
# 2.963247774100164
# 2.9465693483637896
# 0.4420874142037376

# %%
data = np.array([raw_data[0], raw_data[4]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "arg2"])
avg = np.mean(dataframe["arg2"])
print(avg)

plot = sns.jointplot(data=dataframe, x="time", y="arg2", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["arg2"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["arg2"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
# Out:
# 2.963247774100164

# %% [markdown]
# # Ligand 14

# %% [markdown]
# ## Ligand

# %%
# times, ligand_water_distances, histidine_water_distances1, histidine_water_distances2, arginine_water_distances1, arginine_water_distances2
raw_data = np.load("../outputs/water_hb_ligand_14_his_arg.npy", allow_pickle=True)
data = np.array([raw_data[0], raw_data[1]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "ligand"])

avg = np.mean(dataframe["ligand"])
print(avg)
med = np.median(dataframe["ligand"])
print(med)
std = np.std(dataframe["ligand"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="ligand", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["ligand"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["ligand"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()
# Out:
# 3.988721672344639
# 3.6598470417684252
# 1.2334717132333153

# %% [markdown]
# ## Histidine

# %%
data = np.array([raw_data[0], raw_data[2]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "his1"])
avg = np.mean(dataframe["his1"])
print(avg)
med = np.median(dataframe["his1"])
print(med)
std = np.std(dataframe["his1"])
print(std)
plot = sns.jointplot(data=dataframe, x="time", y="his1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["his1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["his1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
# Out:
# 3.9723483813940885
# 3.8436064308456173
# 0.8820348501759049

# %% [markdown]
# ## Arginine

# %%
data = np.array([raw_data[0], raw_data[4]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "arg1"])
avg = np.mean(dataframe["arg1"])
print(avg)
med = np.median(dataframe["arg1"])
print(med)
std = np.std(dataframe["arg1"])
print(std)
plot = sns.jointplot(data=dataframe, x="time", y="arg1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["arg1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["arg1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()
# Out:
# 3.0042901214777094
# 2.978110485080564
# 0.6346278250634144

# %% [markdown]
# # Ligand 13

# %% [markdown]
# ## Ligand

# %%
# times, ligand_water_distances, histidine_water_distances1, histidine_water_distances2, arginine_water_distances1, arginine_water_distances2
raw_data = np.load("../outputs/water_hb_ligand_13_his_arg.npy", allow_pickle=True)
data = np.array([raw_data[0], raw_data[1]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "ligand"])

avg = np.mean(dataframe["ligand"])
print(avg)
med = np.median(dataframe["ligand"])
print(med)
std = np.std(dataframe["ligand"])
print(std)
sns.set(context="notebook", palette="colorblind", style="ticks", font_scale=2)

plot = sns.jointplot(data=dataframe, x="time", y="ligand", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["ligand"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["ligand"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")
plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()
# Out:
# 3.5331931930774765
# 3.332786145097208
# 0.871843721313658

# %% [markdown]
# ## Histidine

# %%
data = np.array([raw_data[0], raw_data[2]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "his1"])
avg = np.mean(dataframe["his1"])
print(avg)
med = np.median(dataframe["his1"])
print(med)
std = np.std(dataframe["his1"])
print(std)
plot = sns.jointplot(data=dataframe, x="time", y="his1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["his1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["his1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
# Out:
# 3.6060553974526863
# 3.577791794647765
# 0.612132448221983

# %% [markdown]
# ## Arginine

# %%
data = np.array([raw_data[0], raw_data[4]])
data_transpose = np.transpose(data)

dataframe = pd.DataFrame(data_transpose, columns=["time", "arg1"])
avg = np.mean(dataframe["arg1"])
print(avg)
med = np.median(dataframe["arg1"])
print(med)
std = np.std(dataframe["arg1"])
print(std)
plot = sns.jointplot(data=dataframe, x="time", y="arg1", kind="scatter", color="#0099AB")
plot.ax_joint.cla()
plt.sca(plot.ax_joint)
plt.scatter(dataframe["time"], dataframe["arg1"], c="white")
plot.ax_joint.plot(dataframe["time"], dataframe["arg1"], color="black", alpha=0.8)
# plot.ax_joint.hlines(avg, 0, 2000, lw=2, color="#D0006F")
# plot.ax_joint.hlines(med, 0, 2000, lw=2, color="#68246D")

plt.gcf().set_size_inches(8, 8)
plot.set_axis_labels("Time (ps)", "Distance (Å)")
plt.setp(plot.ax_marg_x.patches, color="w")
# plt.setp(plot.ax_marg_x.spines, color="w")
plot.ax_marg_x.remove() 
plot.ax_joint.spines["top"].set_visible(True)
sns.despine()
plt.tight_layout()
# Out:
# 2.7625245520962873
# 2.6909911489041747
# 0.5610818432472868

# %% [markdown]
# # Kruskal-Wallis

# %%
import scipy.stats

# %%
raw_data_9 = np.load("../outputs/water_hb_ligand_9_his_arg.npy", allow_pickle=True)
data_9 = np.array([raw_data_9[0], raw_data_9[1]])
data_transpose_9 = np.transpose(data_9)
dataframe_9 = pd.DataFrame(data_transpose_9, columns=["time", "ligand"])
ligand_9 = dataframe_9["ligand"].to_numpy()


raw_data_14 = np.load("../outputs/water_hb_ligand_14_his_arg.npy", allow_pickle=True)
data_14 = np.array([raw_data_14[0], raw_data_14[1]])
data_transpose_14 = np.transpose(data_14)
dataframe_14 = pd.DataFrame(data_transpose_14, columns=["time", "ligand"])
ligand_14 = dataframe_14["ligand"].to_numpy()
kw = scipy.stats.kruskal(ligand_9, ligand_14)
print(kw)
# Out:
# KruskalResult(statistic=27.448242372671757, pvalue=1.6135545088852244e-07)

# %%
raw_data_9 = np.load("../outputs/water_hb_ligand_9_his_arg.npy", allow_pickle=True)
data_9 = np.array([raw_data_9[0], raw_data_9[1]])
data_transpose_9 = np.transpose(data_9)
dataframe_9 = pd.DataFrame(data_transpose_9, columns=["time", "ligand"])
ligand_9 = dataframe_9["ligand"].to_numpy()


raw_data_16 = np.load("../outputs/water_hb_ligand_16_his_arg.npy", allow_pickle=True)
data_16 = np.array([raw_data_16[0], raw_data_16[1]])
data_transpose_16 = np.transpose(data_16)
dataframe_16 = pd.DataFrame(data_transpose_16, columns=["time", "ligand"])
ligand_16 = dataframe_16["ligand"].to_numpy()
kw = scipy.stats.kruskal(ligand_9, ligand_16)
print(kw)
# Out:
# KruskalResult(statistic=77.80403560263767, pvalue=1.1378744712649656e-18)
